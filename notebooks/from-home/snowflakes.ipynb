# %%
# First, install the required Snowflake packages
# !pip install snowflake-snowpark-python snowflake-connector-python

# Add this line to force restart the kernel
import sys
print("Please restart the kernel now (Kernel > Restart) and then run the imports in a new cell")
# Out:
# Requirement already satisfied: snowflake-snowpark-python in /opt/anaconda3/lib/python3.12/site-packages (1.43.0)
# Requirement already satisfied: snowflake-connector-python in /opt/anaconda3/lib/python3.12/site-packages (4.1.1)
# Requirement already satisfied: setuptools>=40.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (75.1.0)
# Requirement already satisfied: wheel in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (0.44.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (4.11.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (6.0.1)
# Requirement already satisfied: cloudpickle!=2.1.0,!=2.2.0,<=3.1.1,>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (3.0.0)
# Requirement already satisfied: protobuf<6.32,>=3.20 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (4.25.3)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (2.9.0.post0)
# Requirement already satisfied: tzlocal in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (5.3.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cryptography>=44.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (46.0.3)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=24.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (25.3.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2.10.1)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2024.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2.32.5)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (24.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.3.2)
# Requirement already satisfied: idna<4,>=3.7 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.7)
# Requirement already satisfied: certifi>=2024.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2025.8.3)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.13.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.10.0)
# Requirement already satisfied: tomlkit in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (0.11.1)
# Requirement already satisfied: boto3>=1.24 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (1.42.4)
# Requirement already satisfied: botocore>=1.24 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (1.42.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from boto3>=1.24->snowflake-connector-python) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /opt/anaconda3/lib/python3.12/site-packages (from boto3>=1.24->snowflake-connector-python) (0.16.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/anaconda3/lib/python3.12/site-packages (from botocore>=1.24->snowflake-connector-python) (2.2.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography>=44.0.1->snowflake-connector-python) (2.0.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil->snowflake-snowpark-python) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=44.0.1->snowflake-connector-python) (2.21)
# Please restart the kernel now (Kernel > Restart) and then run the imports in a new cell

# %%
# First, install the required Snowflake packages
# !pip install snowflake-snowpark-python snowflake-connector-python

# After installation completes, you can import the modules
from snowflake.snowpark import Session # For Snowflake compute engine connection
from snowflake.core import Root, CreateMode # For core operations
from snowflake.core.database import Database # For database operations
from snowflake.core.schema import Schema # For schema operations
from snowflake.core.warehouse import Warehouse # For compute engine operations
from snowflake.core.table import Table, TableColumn, TableCollection # For table operations
from snowflake.core.role import Role, Securable # For role operations
from snowflake.core.stage import Stage, StageDirectoryTable # For stage operations
from snowflake.core.dynamic_table import DynamicTable, DownstreamLag, UserDefinedLag, DynamicTableCollection # For dynamic table operations
from snowflake.snowpark.types import * # For defining DataFrame schema
from snowflake.snowpark import functions as F # For DataFrame functions
# Out:
# Requirement already satisfied: snowflake-snowpark-python in /opt/anaconda3/lib/python3.12/site-packages (1.43.0)
# Requirement already satisfied: snowflake-connector-python in /opt/anaconda3/lib/python3.12/site-packages (4.1.1)
# Requirement already satisfied: setuptools>=40.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (75.1.0)
# Requirement already satisfied: wheel in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (0.44.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (4.11.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (6.0.1)
# Requirement already satisfied: cloudpickle!=2.1.0,!=2.2.0,<=3.1.1,>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (3.0.0)
# Requirement already satisfied: protobuf<6.32,>=3.20 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (4.25.3)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (2.9.0.post0)
# Requirement already satisfied: tzlocal in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-snowpark-python) (5.3.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cryptography>=44.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (46.0.3)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=24.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (25.3.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2.10.1)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2024.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2.32.5)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (24.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.3.2)
# Requirement already satisfied: idna<4,>=3.7 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.7)
# Requirement already satisfied: certifi>=2024.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2025.8.3)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.13.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.10.0)
# Requirement already satisfied: tomlkit in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (0.11.1)
# Requirement already satisfied: boto3>=1.24 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (1.42.4)
# Requirement already satisfied: botocore>=1.24 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (1.42.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from boto3>=1.24->snowflake-connector-python) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /opt/anaconda3/lib/python3.12/site-packages (from boto3>=1.24->snowflake-connector-python) (0.16.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/anaconda3/lib/python3.12/site-packages (from botocore>=1.24->snowflake-connector-python) (2.2.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography>=44.0.1->snowflake-connector-python) (2.0.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil->snowflake-snowpark-python) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=44.0.1->snowflake-connector-python) (2.21)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       2 get_ipython().system('pip install snowflake-snowpark-python snowflake-connector-python')
#       4 # After installation completes, you can import the modules
# ----> 5 from snowflake.snowpark import Session # For Snowflake compute engine connection
#       6 from snowflake.core import Root, CreateMode # For core operations
#       7 from snowflake.core.database import Database # For database operations
#
# ModuleNotFoundError: No module named 'snowflake'

# %%
# THIS CELL FOR OPTION A ONLY

# Replace these with your Snowflake account details
# Follow along with Gilberto for guidance on how to fill these out

connection_parameters = {
    "account": "QMXEUIU-ZZC92584",
    "user": "YYACHRUTI",
    "password": "Mykungfu2003--",
    "role": "ACCOUNTADMIN",
    "warehouse": "COMPUTE_WH"
}

# Create a session
session = Session.builder.configs(connection_parameters).create()
print(f"❄️ Connected to Snowflake account: {session.get_current_account()}")
print(f"Current role: {session.get_current_role()}")
